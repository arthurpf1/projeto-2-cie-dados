# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile 
df = pd.read_excel('tweets_RTX 2080_201809061742.xlsx')
data = pd.read_excel( 'tweets_RTX 2080_201809061742.xlsx', sheetname=1 )
# Out:
# C:\Users\arthu\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#                                                  Teste
# 0    i liked a @youtube video https://t.co/fzlvnkn8...
# 1    rt @ajollygoodscrub: mystblue &amp; i are givi...
# 2    rt @play_rune: need an upgrade? get ready for ...
# 3    micron’s new memory brings plenty of performan...
# 4    win a free 2080 asus  geforce rtx hdmi graphic...
# 5    rt @tweaktown: next-gen gaming laptops coming ...
# 6    rt @crypto_n1: 🎉 crazzie rtx 2080 #giveaway\n\...
# 7    rt @play_rune: need an upgrade? get ready for ...
# 8    @t8styham @realbulletbarry i'd rather buy two ...
# 9    the best that the pc has to offer now that nvi...
# 10   rt @play_rune: need an upgrade? get ready for ...
# 11   crazzie pro gear is going crazzie by giving aw...
# 12   @nvidiageforce and @asus_rog  created the rtx ...
# 13   win a free 2080 asus  geforce rtx hdmi graphic...
# 14   win a free 2080 asus  geforce rtx hdmi graphic...
# 15   rt @play_rune: need an upgrade? get ready for ...
# 16   rt @nvidiageforce: we had a blast at #paxwest ...
# 17   rt @craftcomputing: hands-on with rtx 2080 ti,...
# 18   @asus rtx 2080 ti or gtx 1080 ti !?\ntag a fri...
# 19   rt @play_rune: need an upgrade? get ready for ...
# 20   rt @play_rune: need an upgrade? get ready for ...
# 21   rt @crypto_n1: 🎉 crazzie rtx 2080 #giveaway\n\...
# 22   rt @nvidiageforce: we had a blast at #paxwest ...
# 23   rt @play_rune: need an upgrade? get ready for ...
# 24   micron's gddr6 memory debuts in nvidia's gefor...
# 25   rt @play_rune: need an upgrade? get ready for ...
# 26   rt @play_rune: need an upgrade? get ready for ...
# 27   win a free 2080 asus  geforce rtx hdmi graphic...
# 28   nvidia finally officially revealed the new rtx...
# 29   nvidia geforce rtx 2080 giveaway https://t.co/...
# ..                                                 ...
# 170  rt @play_rune: need an upgrade? get ready for ...
# 171  rt @crypto_n1: 🎉 crazzie rtx 2080 #giveaway\n\...
# 172  rt @play_rune: need an upgrade? get ready for ...
# 173  alphacool launches rtx aio liquid coolers with...
# 174  nvidia geforce rtx 2080 reviews go live on sep...
# 175  rt @play_rune: need an upgrade? get ready for ...
# 176  @bitwitkyle love your content but could i have...
# 177  rt @msitweets: unleash the unlimited power of ...
# 178  rt @gmz_glitched: geforce rtx 2080 ti benchmar...
# 179  rt @play_rune: need an upgrade? get ready for ...
# 180  rt @play_rune: need an upgrade? get ready for ...
# 181  win a free 2080 asus  geforce rtx hdmi graphic...
# 182  rt @play_rune: need an upgrade? get ready for ...
# 183  rt @play_rune: need an upgrade? get ready for ...
# 184  rt @play_rune: need an upgrade? get ready for ...
# 185  rt @play_rune: need an upgrade? get ready for ...
# 186  win a free 2080 asus  geforce rtx hdmi graphic...
# 187  evga muestra sus rtx 2080 y rtx 2080 ti hydro ...
# 188  rt @crypto_n1: 🎉 crazzie rtx 2080 #giveaway\n\...
# 189  rt @play_rune: need an upgrade? get ready for ...
# 190  geforce rtx 2080 ti benchmark compared to the ...
# 191  battlefield 5 with rtx 2080 ti https://t.co/pa...
# 192  nvidia geforce rtx 2080 giveaway https://t.co/...
# 193  i liked a @youtube video https://t.co/yuo3ac2s...
# 194  win a free 2080 asus  geforce rtx hdmi graphic...
# 195  rt @videocardz: nvidia geforce rtx 2080 review...
# 196  i liked a @youtube video https://t.co/lslgobbx...
# 197  metro exodus can't manage 60 fps with rtx enab...
# 198  rt @play_rune: need an upgrade? get ready for ...
# 199  rt @play_rune: need an upgrade? get ready for ...
#
# [200 rows x 1 columns]

# %%
#df.replace("win", "BANANA")
#"Hello people".replace("e", "")
#"Hllo popl"

for i in range (len(df)+1):
    df[i:i+1].replace("?", "")
df
# Out:
#                                            Treinamento
# 0    i liked a @youtube video https://t.co/a0ttjcgw...
# 1    micron's gddr6 memory debuts in nvidia's gefor...
# 2    @edgygamergirl @crystei the rtx 2080 isn't out...
# 3    rt @inq: nvidia geforce rtx 2080 ti only 35 pe...
# 4    rt @play_rune: need an upgrade? get ready for ...
# 5    rt @nvidiageforce: that's a wrap from our #gra...
# 6    alphacool launches rtx aio liquid coolers with...
# 7    rt @play_rune: need an upgrade? get ready for ...
# 8    @mdgames_tw lololol!! i know that video you up...
# 9    win a free 2080 asus  geforce rtx hdmi graphic...
# 10   rt @play_rune: need an upgrade? get ready for ...
# 11   nvidia geforce rtx 2080 giveaway https://t.co/...
# 12   i liked a @youtube video https://t.co/ifwvgtmb...
# 13   @jons253 @battlefield @xbox the rtx 2080 has d...
# 14   nvidia geforce rtx 2080 release date, news and...
# 15   rt @play_rune: need an upgrade? get ready for ...
# 16   rt @play_rune: need an upgrade? get ready for ...
# 17   rt @play_rune: need an upgrade? get ready for ...
# 18   rt @vastagency: @play_rune poggers! @play_rune...
# 19   the best that the pc has to offer now that nvi...
# 20   nvidia geforce rtx 2080 giveaway https://t.co/...
# 21   rt @ajollygoodscrub: mystblue &amp; i are givi...
# 22   battlefield v xbox one x vs rtx 2080 ti early ...
# 23   those voting xbox and/or pc are clearly delusi...
# 24   hey @nvidiageforce @nvidia , i have a single s...
# 25   rt @lyncconfgaming: nvidia finally officially ...
# 26   win a free 2080 asus  geforce rtx hdmi graphic...
# 27   rt @play_rune: need an upgrade? get ready for ...
# 28   rt @esvdiamond: we are more involved in gaming...
# 29   rt @play_rune: need an upgrade? get ready for ...
# ..                                                 ...
# 270  rt @play_rune: need an upgrade? get ready for ...
# 271  .@teamevga unveils new water-cooled @nvidiagef...
# 272  rt @crypto_n1: 🎉 crazzie rtx 2080 #giveaway\n\...
# 273  rt @gmz_glitched: geforce rtx 2080 ti benchmar...
# 274  rt @play_rune: need an upgrade? get ready for ...
# 275  rt @play_rune: need an upgrade? get ready for ...
# 276  nvidia geforce rtx 2080 giveaway https://t.co/...
# 277  rt @play_rune: need an upgrade? get ready for ...
# 278  rt @deepcoolglobal: this was how peter brands ...
# 279  buy me an rtx 2080 ti and i'll help you solve ...
# 280  rt @play_rune: need an upgrade? get ready for ...
# 281  rt @videocardz: nvidia geforce rtx 2080 review...
# 282  rt @play_rune: need an upgrade? get ready for ...
# 283  rt @play_rune: need an upgrade? get ready for ...
# 284  rt @play_rune: need an upgrade? get ready for ...
# 285  rt @play_rune: need an upgrade? get ready for ...
# 286  win a free 2080 asus  geforce rtx hdmi graphic...
# 287  nvidia reveals $800 geforce rtx 2080 at gamesc...
# 288  alphacool launches rtx aio liquid coolers with...
# 289  nvidia geforce rtx 2080 giveaway https://t.co/...
# 290  rt @play_rune: need an upgrade? get ready for ...
# 291  me ha gustado un vídeo de @youtube (https://t....
# 292  rt @play_rune: need an upgrade? get ready for ...
# 293  rt @play_rune: need an upgrade? get ready for ...
# 294  rt @play_rune: need an upgrade? get ready for ...
# 295  rt @videocardz: nvidia geforce rtx 2080 review...
# 296  rt @play_rune: need an upgrade? get ready for ...
# 297  rt @play_rune: need an upgrade? get ready for ...
# 298  win a free 2080 asus  geforce rtx hdmi graphic...
# 299  https://t.co/sjpbaq9vj4 nvidia rtx 2080: here'...
#
# [300 rows x 1 columns]
